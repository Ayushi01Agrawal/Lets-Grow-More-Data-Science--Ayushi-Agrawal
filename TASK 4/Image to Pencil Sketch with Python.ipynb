# %% [markdown]
# # LETS GROW MORE DATA SCIENCE INTERN MARCH 2023
#
# # Beginner Level Task:
#
#
# ## TASK-3- Image to Pencil Sketch with Python:
#
# **We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.**

# %% [markdown]
# ## Importing openCV2 Library

# %%
import cv2
from matplotlib import pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# ## Read the image

# %%
imag=cv2.imread("bird.webp")

# %%
plt.imshow(imag)
b,q,r = cv2.split(imag)
imag = cv2.merge((r,q,b))

# %%
plt.title("Original Image")
plt.imshow(imag)

# %% [markdown]
# ## Creating a new image by converting the original image to greyscale

# %%
imag = mpimg.imread("bird.webp")
R, G, B = img[:,:,0], img[:,:,1], img[:,:,2]
imgGray = 0.2989 * R + 0.5870 * G + 0.1140 * B
plt.imshow(imgGray, cmap='gray')
plt.title("GrayScale Image")
plt.show()

# %% [markdown]
# ## Inverting the new grayscale image

# %%
imag_gray = cv2.cvtColor(imag, cv2.COLOR_BGR2GRAY)
imag_invert = cv2.bitwise_not(imag_gray)
plt.figure(figsize=(8,8))
plt.imshow(imag_invert,cmap="gray")
plt.axis("off")
plt.title("Inverted Image")
plt.show()

# %%
img_smoothing = cv2.GaussianBlur(imag_invert, (21, 21),sigmaX=0, sigmaY=0)
plt.figure(figsize=(8,8))
plt.imshow(img_smoothing,cmap="gray")
plt.axis("off")
plt.title("Smoothen Image")
plt.show()

# %% [markdown]
# ## Inverting the blurred image and then we can easily convert the image into a pencil sketch

# %%
final = cv2.divide(imag_gray, 255 - img_smoothing, scale=255)
plt.figure(figsize=(8,8))
plt.imshow(final,cmap="gray")
plt.axis("off")
plt.title("Final Sketch Image")
plt.show()

# %% [markdown]
# ## looking at both the original image and the pencil sketch

# %%
plt.figure(figsize=(20,20))
plt.subplot(1,2,1)
plt.title('Original image', size=10)
plt.imshow(img)
plt.axis('off')
plt.subplot(1,2,2)
plt.title('final sketch', size=10)
final=cv2.cvtColor( final , cv2.COLOR_BGR2RGB)
plt.imshow( final )
plt.axis('off')
plt.show()
